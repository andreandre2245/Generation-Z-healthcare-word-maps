# %%
import multidict as multidict

import numpy as np
import pandas as pd

import os
import re
from PIL import Image
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def getFrequencyDictForText(sentence):
    fullTermsDict = multidict.MultiDict()
    tmpDict = {}

    # making dict for counting frequencies
    for text in sentence.split(" "):
        if re.match("a|the|an|the|to|in|for|of|or|by|with|is|on|that|be", text):
            continue
        val = tmpDict.get(text, 0)
        tmpDict[text.lower()] = val + 1
    for key in tmpDict:
        fullTermsDict.add(key, tmpDict[key])
    return fullTermsDict


def makeImage(text):
    medicine_mask = np.array(Image.open("medicinecross_mask2.png"))

    wc = WordCloud(width=1000, height=500, scale=1, background_color="white", max_words=100, min_font_size = 10, mask=medicine_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    plt.figure(figsize=(80, 60))
    plt.rcParams.update({'figure.figsize': (16,12)})


text = open('Wellbeing_TN.txt', encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))

#wc.to_file("wordcloud.png")

# %%
def makeImage(text):
    medicine_mask = np.array(Image.open("medicine_mask.png"))

    wc = WordCloud(width=1000, height=500, scale=1, background_color="white", max_words=400, min_font_size = 5, mask=medicine_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    plt.figure(figsize=(80, 60))
    plt.rcParams.update({'figure.figsize': (16,12)})


text = open('Combined_TN.txt', encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))

#wc.to_file("wordcloud.png")

# %%
def makeImage(text):
    medicine_mask = np.array(Image.open("medicinecross_mask1.png"))

    wc = WordCloud(width=1000, height=500, scale=1, background_color="white", max_words=100, min_font_size = 5, mask=medicine_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    plt.figure(figsize=(80, 60))
    plt.rcParams.update({'figure.figsize': (16,12)})


text = open('Healthcare_TN.txt', encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))

#wc.to_file("wordcloud.png")

# %%
def makeImage(text):
    medicine_mask = np.array(Image.open("Syringe_mask.png"))

    wc = WordCloud(width=1000, height=500, scale=1, background_color="white", max_words=400, min_font_size = 3, mask=medicine_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    plt.figure(figsize=(80, 60))
    plt.rcParams.update({'figure.figsize': (16,12)})


text = open('Healthcare_TN.txt', encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))

#wc.to_file("wordcloud.png")

# %%
def makeImage(text):
    
    wc = WordCloud(width=1000, height=500, scale=1, background_color="white", max_words=200, min_font_size = 10,)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    plt.figure(figsize=(80, 60))
    plt.rcParams.update({'figure.figsize': (16,12)})


text = open('Wellbeing_TN.txt', encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))

#wc.to_file("wordcloud.png")
